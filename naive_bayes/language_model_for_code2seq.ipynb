# %%
import collections
from collections import Counter
import csv
import nltk
from nltk.lm.preprocessing import padded_everygram_pipeline
import string
from typing import Dict, List, Tuple, Optional

# %%
def get_sentence_tokens_and_tags(sentence: str) -> List[Tuple[str, str]]:
    sentence_without_punctuation = sentence.translate(str.maketrans('', '', string.punctuation))
    tokens = nltk.word_tokenize(sentence_without_punctuation)
    return nltk.pos_tag(tokens)

def get_sentence_tags(sentence: str) -> List[str]:
    tokens: List[Tuple[str, str]] = get_sentence_tokens_and_tags(sentence)
#     print(tokens)
    only_tags: List[str] = []
    
    for _, tag in tokens:
        only_tags.append(tag)
#     print(only_tags)
    return only_tags

# %%
# test for tagging 

print(get_sentence_tags("This commit was manufactured by cvs2svn to create branch 'lesya'"))
print(get_sentence_tags("fixes: sorting of resource bundle properties in UI Designer; extra method invocation when finding classes in Debugger; resource bundles in UI designer can be used even if they are located in non-default package"))
# Out:
# [('This', 'DT'), ('commit', 'NN'), ('was', 'VBD'), ('manufactured', 'VBN'), ('by', 'IN'), ('cvs2svn', 'NN'), ('to', 'TO'), ('create', 'VB'), ('branch', 'NN'), ('lesya', 'NN')]
# ['DT', 'NN', 'VBD', 'VBN', 'IN', 'NN', 'TO', 'VB', 'NN', 'NN']
# ['DT', 'NN', 'VBD', 'VBN', 'IN', 'NN', 'TO', 'VB', 'NN', 'NN']
# [('fixes', 'NNS'), ('sorting', 'VBG'), ('of', 'IN'), ('resource', 'NN'), ('bundle', 'NN'), ('properties', 'NNS'), ('in', 'IN'), ('UI', 'NNP'), ('Designer', 'NNP'), ('extra', 'JJ'), ('method', 'NN'), ('invocation', 'NN'), ('when', 'WRB'), ('finding', 'VBG'), ('classes', 'NNS'), ('in', 'IN'), ('Debugger', 'NNP'), ('resource', 'NN'), ('bundles', 'NNS'), ('in', 'IN'), ('UI', 'NNP'), ('designer', 'NN'), ('can', 'MD'), ('be', 'VB'), ('used', 'VBN'), ('even', 'RB'), ('if', 'IN'), ('they', 'PRP'), ('are', 'VBP'), ('located', 'VBN'), ('in', 'IN'), ('nondefault', 'NN'), ('package', 'NN')]
# ['NNS', 'VBG', 'IN', 'NN', 'NN', 'NNS', 'IN', 'NNP', 'NNP', 'JJ', 'NN', 'NN', 'WRB', 'VBG', 'NNS', 'IN', 'NNP', 'NN', 'NNS', 'IN', 'NNP', 'NN', 'MD', 'VB', 'VBN', 'RB', 'IN', 'PRP', 'VBP', 'VBN', 'IN', 'NN', 'NN']
# ['NNS', 'VBG', 'IN', 'NN', 'NN', 'NNS', 'IN', 'NNP', 'NNP', 'JJ', 'NN', 'NN', 'WRB', 'VBG', 'NNS', 'IN', 'NNP', 'NN', 'NNS', 'IN', 'NNP', 'NN', 'MD', 'VB', 'VBN', 'RB', 'IN', 'PRP', 'VBP', 'VBN', 'IN', 'NN', 'NN']

# %%
# get dataset for actual messages
data_file = "/Users/natalia.murycheva/Documents/code2seq/result.aurora.correct.csv"
commit_vs_message: Dict[str, str] = {}
commit_vs_tags: Dict[str, List[str]] = {}
commit_index = 0
actual_message_index = 3
i = 0   

with open(data_file, newline='') as f:
    reader = csv.reader(f, delimiter='^')
    is_first = True
    last_commit = ""
    
    for row in reader:
        if is_first:
            last_commit = row[commit_index]
            is_first = False
            
        if row[commit_index] != "":
            last_commit = row[commit_index]
        
            if row[actual_message_index] != "":
                commit_vs_message[last_commit] = row[actual_message_index]
                tags = get_sentence_tags(row[actual_message_index])
                if tags:                    
                    i += 1
                    commit_vs_tags[last_commit] = tags
                    
print(f"Number of messages = {i}")
# Out:
# Number of messages = 16923

# %%
len(commit_vs_tags)
# Out:
# 16923

# %%
tags_dataset: List[List[str]] = []
    
for key, value in commit_vs_tags.items():
    tags_dataset.append(value)

# %%
print(tags_dataset[:10])
# Out:
# [['NN'], ['NN'], ['NNS'], ['NN'], ['NN'], ['DT', 'NN', 'VBD', 'VBN', 'IN', 'NN', 'TO', 'VB', 'NN', 'NN'], ['NN'], ['NN'], ['NN'], ['NN']]

# %% [markdown]
# # Bigram Language Model

# %%
from nltk.lm import MLE

n = 3
train, padded = padded_everygram_pipeline(n, tags_dataset)
model = MLE(n)

# %%
for i, a in enumerate(train):
    print(list(a))
    if i > 15:
        break
# Out:
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NNS',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NNS'), ('NNS', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NNS'), ('<s>', 'NNS', '</s>'), ('NNS', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('DT',), ('NN',), ('VBD',), ('VBN',), ('IN',), ('NN',), ('TO',), ('VB',), ('NN',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'DT'), ('DT', 'NN'), ('NN', 'VBD'), ('VBD', 'VBN'), ('VBN', 'IN'), ('IN', 'NN'), ('NN', 'TO'), ('TO', 'VB'), ('VB', 'NN'), ('NN', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'DT'), ('<s>', 'DT', 'NN'), ('DT', 'NN', 'VBD'), ('NN', 'VBD', 'VBN'), ('VBD', 'VBN', 'IN'), ('VBN', 'IN', 'NN'), ('IN', 'NN', 'TO'), ('NN', 'TO', 'VB'), ('TO', 'VB', 'NN'), ('VB', 'NN', 'NN'), ('NN', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]
# [('<s>',), ('<s>',), ('NN',), ('</s>',), ('</s>',), ('<s>', '<s>'), ('<s>', 'NN'), ('NN', '</s>'), ('</s>', '</s>'), ('<s>', '<s>', 'NN'), ('<s>', 'NN', '</s>'), ('NN', '</s>', '</s>')]

# %%
model.fit(train, padded)

# %%
# model.score('is', 'language'.split())  # P('is'|'language')
# model.score('never', 'language is'.split())  # P('never'|'language is')

print(model.score('NN', 'IN'.split()))
print(model.score('VBN', 'VBD'.split()))
print(model.score('VBN', 'NN VBD'.split()))
# Out:
# 0.40547703180212014
# 0.0525092936802974
# 0.2515923566878981

# %%
print(model.counts['NN'])
print(model.counts['<s>'])
print(model.counts['</s>'])
# Out:
# 16873
# 33812
# 33812

# %% [markdown]
# # Filter predicted tags

# %%
# get data
commit_vs_predicted_message: Dict[str, List[List[Tuple[str, str]]]] = collections.defaultdict(list)
    
commit_index = 0
predicted_message_index = 5
    

with open(data_file, newline='') as f:
    reader = csv.reader(f, delimiter='^')
    is_first = True
    last_commit = ""
    
    for row in reader:
        if is_first:
            last_commit = row[commit_index]
            is_first = False
            
        if row[commit_index] != "":
            last_commit = row[commit_index]
        
        predicted_message = row[predicted_message_index]
        if predicted_message != "":
            tokens_and_tags = get_sentence_tokens_and_tags(predicted_message)
            if tokens_and_tags:
                commit_vs_predicted_message[last_commit].append(tokens_and_tags)

# %%
j = 0
for key, value in commit_vs_predicted_message.items():
    j += 1
    if j > 5:
        break
    print(value)
# Out:
# [[('first', 'RB'), ('replace', 'VB'), ('statement', 'NN'), ('expression', 'NN'), ('implementation', 'NN'), ('used', 'VBN'), ('to', 'TO'), ('enable', 'VB'), ('the', 'DT'), ('testing', 'NN')], [('first', 'RB'), ('replace', 'VB'), ('statement', 'NN'), ('expression', 'NN'), ('implementation', 'NN'), ('used', 'VBN'), ('to', 'TO'), ('enable', 'VB'), ('the', 'DT'), ('testing', 'NN')]]
# [[('add', 'VB'), ('support', 'NN'), ('for', 'IN'), ('different', 'JJ'), ('license', 'NN'), ('managers', 'NNS'), ('ui', 'VBP'), ('bug', 'NN')]]
# [[('fixed', 'VBN'), ('issue', 'NN'), ('with', 'IN'), ('not', 'RB'), ('external', 'JJ'), ('up', 'RP'), ('in', 'IN'), ('xml', 'NN')], [('added', 'VBD'), ('css', 'NN'), ('xhtml', 'NNP'), ('binding', 'VBG'), ('second', 'JJ'), ('cut', 'NN'), ('specified', 'VBN'), ('if', 'IN')], [('added', 'JJ'), ('usage', 'NN'), ('view', 'NN'), ('to', 'TO'), ('openapi', 'VB'), ('bundle', 'JJ'), ('been', 'VBN'), ('check', 'VB'), ('start', 'NN')]]
# [[('fixes', 'NNS'), ('sorting', 'VBG'), ('of', 'IN'), ('resource', 'NN'), ('bundle', 'NN'), ('properties', 'NNS'), ('for', 'IN'), ('ui', 'JJ'), ('designer', 'NN'), ('extra', 'JJ')], [('fixed', 'VBN'), ('read', 'JJ'), ('access', 'NN'), ('allowed', 'VBN'), ('assertion', 'NN'), ('access', 'NN'), ('unmatched', 'VBD'), ('for', 'IN')], [('fixes', 'NNS'), ('sorting', 'VBG'), ('of', 'IN'), ('resource', 'NN'), ('bundle', 'NN'), ('properties', 'NNS'), ('in', 'IN'), ('ui', 'JJ'), ('designer', 'NN'), ('extra', 'JJ')], [('sh', 'NN'), ('mem', 'NN'), ('for', 'IN'), ('j', 'NN'), ('num', 'NN'), ('ee', 'NN'), ('bug', 'NN'), ('dialog', 'NN')], [('fixes', 'NNS'), ('sorting', 'VBG'), ('of', 'IN'), ('resource', 'NN'), ('bundle', 'NN'), ('properties', 'NNS'), ('in', 'IN'), ('ui', 'JJ'), ('designer', 'NN'), ('extra', 'JJ')], [('fixes', 'NNS'), ('sorting', 'VBG'), ('of', 'IN'), ('resource', 'NN'), ('bundle', 'NN'), ('properties', 'NNS'), ('for', 'IN'), ('ui', 'JJ'), ('designer', 'NN'), ('extra', 'JJ')], [('fixes', 'NNS'), ('in', 'IN'), ('tests', 'NNS'), ('tei', 'NNS'), ('and', 'CC'), ('tld', 'JJ'), ('get', 'NN'), ('file', 'NN')], [('scr', 'NN'), ('num', 'CC'), ('helper', 'NN'), ('should', 'MD'), ('get', 'VB'), ('start', 'VB')], [('fixes', 'NNS'), ('in', 'IN'), ('tests', 'NNS'), ('and', 'CC'), ('tld', 'JJ'), ('get', 'NN'), ('file', 'NN')]]
# [[('tabs', 'NNS'), ('refactored', 'VBD'), ('to', 'TO'), ('outer', 'VB'), ('space', 'NN'), ('custom', 'NN'), ('section', 'NN'), ('evaluation', 'NN')]]

# %%
def get_proba(tag: str, resulted_token_and_tags: List[Tuple[str, str]]) -> float:
    global model
    if len(resulted_token_and_tags) >= 2:
        prev_tag = resulted_token_and_tags[-1][1]
        prev_prev_tag = resulted_token_and_tags[-2][1]

        bigram_proba = model.score(tag, prev_tag)
        threegram_proba = model.score(tag, [prev_prev_tag, prev_tag])

        return bigram_proba + threegram_proba
    else:
        prev_tag = resulted_token_and_tags[-1][1]
        return model.score(tag, prev_tag)

    
def delete_serial_same_tokens(tokens_and_tags: List[Tuple[str, str]]) -> List[Tuple[str, str]]:
    results_tokens = []

    prev = tokens_and_tags[0][0]
    results_tokens.append(tokens_and_tags[0])
    for token, tag in tokens_and_tags[1:]:
        if token != prev:
            results_tokens.append((token, tag))
            prev = token

    return results_tokens

def filter_tags_by_probability(tokens_and_tags: List[Tuple[str, str]], threshold=0.20) -> str:
    resulted_tuples: List[Tuple[str, str]] = []
#     print(tokens_and_tags)
    tokens_and_tags = delete_serial_same_tokens(tokens_and_tags)
#     print(tokens_and_tags)
    size = len(tokens_and_tags)
    mid = size // 2   
    for i in range(mid):
        resulted_tuples.append(tokens_and_tags[i])
    
    for token, tag in tokens_and_tags[mid:]:
        proba = get_proba(tag, resulted_tuples)
        if proba > threshold:
            resulted_tuples.append((token, tag))
    print([token for token, tag in resulted_tuples])        
    return [token for token, tag in resulted_tuples]

# %%
filtered_predicted_messages: Dict[str, List[List[str]]] = collections.defaultdict(list)

for commit in commit_vs_predicted_message.keys():
    for token_and_tags in commit_vs_predicted_message[commit]:
        filtered_predicted_messages[commit].append(filter_tags_by_probability(token_and_tags))
# Out:
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['add', 'support', 'for', 'different', 'license', 'bug']
# ['fixed', 'issue', 'with', 'not']
# ['added', 'css', 'xhtml', 'binding', 'cut', 'if']
# ['added', 'usage', 'view', 'to', 'openapi', 'bundle']
# ['fixes', 'sorting', 'of', 'resource', 'bundle']
# ['fixed', 'read', 'access', 'allowed']
# ['fixes', 'sorting', 'of', 'resource', 'bundle']
# ['sh', 'mem', 'for', 'j', 'num']
# ['fixes', 'sorting', 'of', 'resource', 'bundle']
# ['fixes', 'sorting', 'of', 'resource', 'bundle']
# ['fixes', 'in', 'tests', 'tei']
# ['scr', 'num', 'helper']
# ['fixes', 'in', 'tests']
# ['tabs', 'refactored', 'to', 'outer', 'space', 'custom']
# ['rolled', 'back', 'stathik', 'changes', 'of', 'css']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['fix', 'non', 'compilable', 'code']
# ['rolled', 'back', 'stathik']
# ['fixing', 'non', 'compilable', 'code']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['add', 'page', 'for', 'different']
# ['patterns', 'are', 'separated', 'from', 'editing']
# ['patterns', 'are', 'separated', 'from', 'editing']
# ['added', 'minor', 'methods', 'for', 'use', 'information']
# ['added', 'minor', 'methods', 'for', 'use', 'information']
# ['open', 'source', 'and', 'num', 'year', 'license']
# ['open', 'source', 'and', 'num', 'year', 'license']
# ['sh', 'mem', 'for', 'j', 'num']
# ['open', 'source', 'and', 'num', 'year', 'license']
# ['upgrade', 'deadline']
# ['open', 'source', 'and', 'num', 'year', 'license']
# ['open', 'source', 'and', 'num', 'year', 'license']
# ['scr', 'num']
# ['scr', 'num']
# ['fix', 'scr', 'num', 'tld']
# ['fix', 'for', 'rabrique', 'get']
# ['scr', 'num', 'not', 'short']
# ['fix', 'for', 'gc', 'while', 'body']
# ['fixed', 'tree', 'builder', 'completion']
# ['fixed', 'issue', 'with', 'not', 'working', 'completion', 'for']
# ['jspx', 'formatter', 'test', 'formatter']
# ['tree', 'node', 'extends', 'node', 'for']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['fixing', 'scr', 'num', 'view']
# ['assertions', 'on', 'startup']
# ['minor', 'cleanup', 'vf']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['fixed', 'issue', 'with', 'forgiving', 'selection']
# ['fixes', 'in', 'resolve', 'and', 'completion', 'problems']
# ['new', 'tree', 'structure']
# ['project', 'tree', 'builder', 'test']
# ['form', 'merger', 'parsing', 'test']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['project', 'tree', 'builder', 'test']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['tree', 'node', 'extends', 'node', 'for']
# ['decreased', 'xmx', 'to', 'be', 'num']
# ['extracted', 'abstract', 'tree', 'node', 'and', 'optimized', 'project', 'view']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['tree', 'node', 'extends', 'node', 'for']
# ['tree', 'structure', 'provider']
# ['scr', 'num']
# ['project', 'tree', 'builder', 'test']
# ['fixed', 'issue', 'with', 'saving', 'resource', 'in', 'constructor']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['tree', 'structure', 'provider']
# ['extracted', 'abstract', 'tree', 'node', 'and', 'optimized', 'project', 'view']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['refactored', 'out', 'and', 'removed']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['tree', 'node', 'extends', 'node', 'for']
# ['minor', 'cleanup', 'not', 'keep']
# ['refactored', 'out', 'and', 'removed']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['tree', 'node', 'extends', 'node', 'for']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['tree', 'node', 'contains', 'not', 'file', 'check', 'for']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['fixes', 'in', 'tests', 'tei', 'not']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'parsing', 'completion', 'of', 'string', 'html']
# ['fixing', 'non', 'compilable', 'code', 'around']
# ['scr', 'num']
# ['fixes', 'in', 'tests', 'tei', 'not']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['new', 'xml', 'structure']
# ['new', 'tree', 'structure', 'css']
# ['test', 'manager', 'wrap']
# ['test', 'code', 'option']
# ['test', 'manager']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['indent', 'working', 'wrap', 'to', 'do', 'polished']
# ['indent', 'working', 'wrap', 'to', 'do', 'polished']
# ['indent', 'working', 'wrap', 'to', 'do', 'check']
# ['indent', 'working', 'wrap', 'to', 'do', 'lesya']
# ['new', 'formatter', 'interface']
# ['first', 'variant', 'of', 'group', 'field']
# ['test', 'version', 'of']
# ['supported', 'line', 'comment', 'for', 'css', 'validation', 'bug']
# ['indent', 'working', 'wrap']
# ['test', 'manager']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['visibility', 'comparator', 'fixed', 'tests']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['test', 'version', 'to', 'html', 'interface']
# ['indent', 'working', 'wrap', 'to', 'do', 'interface']
# ['indent', 'working', 'wrap', 'to', 'do', 'lesya']
# ['indent', 'working', 'wrap', 'to', 'do', 'lesya']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['num', 'of', 'wrap', 'done']
# ['improved', 'performance', 'of', 'writeable', 'map', 'action']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['new', 'tree', 'structure', 'into', 'build']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['indent', 'working', 'wrap']
# ['fixed', 'one', 'more', 'html', 'tag']
# ['test', 'manager', 'wrap']
# ['test', 'option', 'updated']
# ['test', 'num']
# ['test', 'before', 'xml']
# ['test']
# ['test', 'manager']
# ['test', 'code', 'placement']
# ['jspx', 'synchronization']
# ['test', 'timebomb']
# ['new', 'tree', 'structure', 'fix']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['scr', 'num', 'option']
# ['new', 'tree', 'structure', 'fix']
# ['test', 'token', 'text']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['fixed', 'npe', 'get', 'that', 'null']
# ['new', 'tree', 'structure', 'into', 'chameleon']
# ['new', 'tree', 'structure', 'into', 'chameleon']
# ['fixed', 'issue', 'with', 'completing', 'n']
# ['scr', 'num', 'helper', 'file']
# ['scr', 'num']
# ['scr', 'num']
# ['fixed', 'npe', 'is']
# ['empty', 'impls', 'for', 'disabled', 'repository', 'check']
# ['scr', 'num']
# ['tree', 'node', 'extends', 'node', 'for']
# ['scr', 'num']
# ['completion', 'fixes', 'and', 'for', 'accessible', 'access']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['scr', 'num']
# ['num', 'of', 'wrap', 'designer']
# ['fixed', 'issue', 'with', 'empty', 'completion', 'like']
# ['scr', 'num']
# ['scr']
# ['fixed', 'issue', 'with', 'saving', 'dir', 'of', 'file']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['rolled', 'back', 'stathik', 'changes']
# ['scr', 'num']
# ['first', 'cut', 'for', 'live', 'templates', 'for', 'search', 'criterias']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['removed', 'old', 'stuff', 'made', 'user', 'history', 'configuration']
# ['scr', 'num']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['scr', 'num', 'get']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'should', 'get']
# ['fixed', 'issue', 'with', 'wrong', 'dir', 'for', 'first', 'find']
# ['fixed', 'issue', 'with', 'not', 'magic', 'completion', 'for', 'lookup']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['added', 'search', 'for', 'module', 'title']
# ['massive', 'changes', 'scr']
# ['massive', 'changes']
# ['scr', 'idea', 'num', 'and', 'tld']
# ['scr', 'num', 'fixed']
# ['rolled', 'back', 'stathik', 'changes']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['add', 'default', 'hint']
# ['add', 'default', 'hint']
# ['massive', 'changes']
# ['add', 'support', 'for', 'different', 'xml', 'lesya']
# ['fixed', 'issue', 'with', 'truncation', 'of', 'number']
# ['massive', 'changes', 'option']
# ['rolled', 'back', 'stathik', 'changes', 'of']
# ['massive', 'changes', 'option']
# ['working', 'on', 'add', 'methods', 'for']
# ['working', 'on', 'add', 'generation', 'fix']
# ['massive', 'changes', 'option']
# ['fixing', 'num', 'if']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['fixed', 'issue', 'with', 'xml']
# ['fix', 'for', 'num', 'positions', 'outside', 'file']
# ['fixing', 'com', 'intellij', 'and', 'impl', 'absent']
# ['massive', 'changes']
# ['fixes', 'in', 'resolve', 'and', 'completion', 'problems']
# ['working', 'on', 'add', 'generation', 'fix']
# ['working', 'on', 'add', 'methods', 'for', 'add']
# ['scr', 'num', 'fixed']
# ['working', 'on', 'add', 'methods', 'for']
# ['working', 'on', 'add', 'methods', 'for', 'add']
# ['working', 'on', 'add', 'generation']
# ['working', 'on', 'add', 'methods', 'for']
# ['scr', 'num', 'view']
# ['working', 'on', 'add', 'methods', 'for']
# ['working', 'on', 'add', 'generation']
# ['fixed', 'issue', 'with', 'process', 'working', 'b', 'for']
# ['fixed', 'issue', 'with', 'truncation', 'of', 'button', 'map']
# ['working', 'on', 'add', 'methods', 'for', 'add']
# ['working', 'on', 'add', 'methods', 'for', 'add']
# ['massive', 'changes']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['jspx', 'synchronization', 'jspx', 'to', 'support']
# ['new', 'xml', 'structure']
# ['test', 'framework', 'fixed', 'used']
# ['first', 'chunk', 'of', 'make', 'optimization', 'field']
# ['tests', 'fixed', 'intellij', 'computed', 'clone']
# ['tests', 'fixed', 'intellij', 'computed', 'clone']
# ['some', 'tests']
# ['some', 'tests', 'fixed']
# ['new', 'code', 'formatter']
# ['scr', 'num']
# ['new', 'tree', 'structure', 'start']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['fixing', 'text', 'functions']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['new', 'xml', 'structure']
# ['scr', 'num', 'added']
# ['fixed', 'issue', 'with', 'highlighting', 'class']
# ['new', 'xml', 'structure']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['massive', 'changes', 'in', 'xml']
# ['fixed', 'startin', 'write', 'action', 'problem']
# ['new', 'xml', 'structure']
# ['massive', 'changes', 'in', 'ant', 'enable']
# ['xml', 'tag', 'get', 'value']
# ['massive', 'changes', 'in', 'completion', 'evaluation']
# ['tree', 'node', 'extends']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['fixed', 'issue', 'with', 'expiring', 'evaluation', 'by', 'url']
# ['new', 'xml', 'structure']
# ['massive', 'changes', 'in', 'xml']
# ['massive', 'changes', 'in', 'xml']
# ['new', 'xml', 'structure']
# ['massive', 'changes', 'in', 'integration']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['fixed', 'npe', 'in', 'file', 'name']
# ['new', 'xml', 'structure']
# ['massive', 'changes', 'in', 'xml']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'tree', 'structure', 'jspx']
# ['massive', 'changes', 'in', 'xml']
# ['massive', 'changes', 'in', 'xml']
# ['tree', 'node', 'extends']
# ['new', 'xml', 'structure']
# ['massive', 'changes', 'in', 'integration']
# ['new', 'xml', 'structure']
# ['tree', 'node', 'extends']
# ['new', 'xml', 'structure']
# ['scr', 'num', 'option']
# ['fix', 'npe', 'file']
# ['pom', 'aspects', 'implemented']
# ['fix', 'scr', 'num', 'file']
# ['pom', 'aspects']
# ['pom', 'aspects', 'implemented', 'for', 'jsp']
# ['pom', 'aspects', 'implemented']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['pom', 'aspects', 'implemented']
# ['pom', 'aspects', 'implemented']
# ['pom', 'aspects', 'implemented']
# ['pom', 'aspects', 'implemented']
# ['jsp', 'fixes', 'is', 'and']
# ['jsp', 'implicit', 'variables', 'rewriten']
# ['fixed', 'npe', 'null', 'null']
# ['scr', 'num', 'and', 'src']
# ['update', 'for', 'resolve', 'and', 'some']
# ['tree', 'node', 'extends', 'fixed', 'for']
# ['scr', 'num', 'and', 'src']
# ['fixes', 'in', 'tests', 'tei']
# ['fixes', 'in', 'tests', 'tei']
# ['decreased', 'xmx', 'to', 'be', 'num']
# ['scr', 'num', 'and', 'src', 'chameleon']
# ['fixed', 'npe', 'on', 'null', 'name', 'file']
# ['fixes', 'in', 'resolve', 'with', 'completion', 'html']
# ['scr', 'num', 'helper', 'structure']
# ['update', 'for', 'resolve', 'and', 'some']
# ['tree', 'node', 'extends']
# ['scr', 'num', 'and', 'src', 'chameleon']
# ['update', 'for', 'resolve', 'and', 'some']
# ['new', 'tree', 'structure']
# ['scr', 'num']
# ['some', 'fixes', 'in', 'jsp', 'tld']
# ['scr', 'num']
# ['scr', 'num', 'get', 'option']
# ['scr', 'num', 'and', 'src']
# ['resolve', 'in', 'multyroot', 'environment']
# ['scr', 'num', 'and', 'src']
# ['more', 'resolve', 'in', 'resolve', 'performance', 'jsp']
# ['new', 'ant', 'support', 'completion', 'added']
# ['scr', 'num', 'view']
# ['update', 'for', 'resolve', 'and', 'some']
# ['update', 'for', 'resolve', 'and', 'some']
# ['fixes', 'for', 'tests', 'of', 'html', 'file']
# ['massive', 'changes', 'in', 'xml']
# ['killing', 'deprecated', 'diff', 'api', 'find']
# ['killing', 'deprecated', 'diff', 'api', 'impl']
# ['scr', 'num']
# ['scr', 'num']
# ['fixing', 'num', 'option']
# ['fixes', 'in', 'tests', 'tei']
# ['scr', 'num', 'fixed']
# ['scr', 'num', 'fixed']
# ['scr', 'num', 'fixed']
# ['scr', 'num', 'fixed']
# ['new', 'tree', 'structure', 'into', 'jspx', 'generation']
# ['new', 'xml', 'structure']
# ['new', 'tree', 'structure', 'if']
# ['new', 'xml', 'structure']
# ['new', 'xml', 'structure']
# ['new', 'tree', 'structure', 'into', 'jspx']
# ['new', 'code', 'formatter', 'version']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['scr', 'num', 'brace']
# ['indent', 'working', 'wrap', 'to', 'do', 'lesya']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap', 'to', 'do', 'lesya']
# ['indent', 'working', 'wrap', 'to', 'do', 'functionality']
# ['indent', 'working', 'wrap']
# ['new', 'tree', 'structure', 'into']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['indent', 'working', 'wrap']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['new', 'tree', 'structure', 'css']
# ['project', 'tree', 'builder', 'test']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['fixed', 'npe', 'is']
# ['fixed', 'one', 'more', 'html', 'tag']
# ['pseudo', 'text', 'array', 'now', 'fully']
# ['fixed', 'npe', 'null', 'null']
# ['fixed', 'npe', 'null', 'that']
# ['fixed', 'npe', 'on', 'file']
# ['scr', 'num', 'helper']
# ['fixed', 'npe', 'is']
# ['fixed', 'npe', 'get', 'that', 'null']
# ['fixed', 'npe', 'null', 'is', 'not', 'mapped', 'file']
# ['fixed', 'npe', 'resolve', 'of', 'class', 'id']
# ['fixed', 'npe']
# ['fixed', 'npe']
# ['fixed', 'npe']
# ['new', 'xml', 'structure']
# ['new', 'ant', 'support', 'test']
# ['scr', 'idea', 'num']
# ['scr', 'num', 'get']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['new', 'xml', 'structure']
# ['scr', 'num', 'not', 'get']
# ['scr', 'num', 'get']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['new', 'xml', 'structure']
# ['scr', 'num']
# ['scr', 'num', 'helper']
# ['fixed', 'issue', 'with', 'user']
# ['scr', 'num']
# ['new', 'resolve', 'schema']
# ['scr', 'num', 'completion', 'via']
# ['scr', 'num', 'and', 'completion', 'tag']
# ['fixed', 'npe', 'null', 'file']
# ['fixed', 'issue', 'with', 'initialization', 'ns']
# ['xml', 'tag', 'impl']
# ['new', 'xml', 'structure']
# ['xml', 'tag', 'merge', 'create']
# ['new', 'xml', 'structure']
# ['events', 'in', 'case']
# ['decreased', 'descriptors', 'to', 'be', 'num']
# ['fixed', 'issue', 'with', 'method', 'constructor']
# ['fixed', 'issue', 'with', 'wrong', 'markup', 'by', 'lexer']
# ['new', 'parser', 'version']
# ['fixed', 'issue', 'with', 'wrong', 'picking', 'markup', 'by', 'lexer']
# ['xml', 'lexer', 'fixed', 'not']
# ['fixed', 'issue', 'with', 'process', 'resource', 'lexer']
# ['fixed', 'issue', 'with', 'wrong', 'markup', 'by', 'lexer']
# ['script', 'is', 'integrated', 'with', 'html']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['scr', 'num', 'and', 'completion']
# ['fix', 'for', 'completion']
# ['fix', 'for', 'is', 'inheritor']
# ['some', 'more', 'filtering', 'class', 'name']
# ['new', 'tree', 'structure', 'into', 'jspx']
# ['fixed', 'issue', 'with', 'process', 'resource', 'lexer']
# ['test', 'fixed', 'around', 'map']
# ['some', 'tests', 'commented', 'jsp']
# ['some', 'tests', 'commented']
# ['fix', 'for', 'rabrique']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['test', 'fixed', 'option', 'for']
# ['xml', 'lexer', 'fixed', 'not']
# ['new', 'parser', 'time']
# ['fixed', 'issue', 'with', 'wrong', 'picking', 'markup', 'by', 'lexer']
# ['scr', 'num']
# ['test', 'fixed', 'around', 'map']
# ['some', 'tests', 'commented']
# ['some', 'tests', 'commented', 'jsp', 'for', 'jsp']
# ['new', 'xml', 'structure']
# ['test', 'fixed', 'option', 'updated']
# ['some', 'tests', 'commented']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'validation', 'finding', 'file', 'from', 'external', 'url']
# ['test', 'fixed', 'around', 'file']
# ['fixed', 'issue', 'with', 'validation', 'finding', 'file', 'from', 'external', 'url']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['some', 'tests', 'fixed', 'ends']
# ['some', 'tests', 'fixed']
# ['test', 'is', 'token', 'in', 'jsp', 'block']
# ['some', 'tests', 'fixed']
# ['some', 'tests', 'fixed']
# ['scr', 'num', 'helper', 'view']
# ['scr', 'idea']
# ['scr', 'num']
# ['scr', 'num']
# ['fixing', 'num', 'leaks', 'jsp']
# ['first', 'cut', 'for', 'repository']
# ['scr', 'num', 'and', 'tag', 'custom']
# ['scr', 'num']
# ['scr', 'num', 'should', 'chameleon']
# ['scr', 'num', 'option']
# ['new', 'tree', 'structure', 'jspx']
# ['new', 'tree', 'structure', 'into', 'jspx']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['new', 'xml', 'structure']
# ['scr', 'num']
# ['added', 'usage', 'view', 'to', 'openapi', 'start']
# ['scr', 'idea', 'num']
# ['first', 'cut', 'for', 'live', 'templates', 'for', 'search', 'criterias']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['scr', 'idea', 'num', 'and', 'tld', 'option']
# ['fixed', 'issue', 'with', 'id', 'reference']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['fixed', 'issue', 'with', 'tag', 't']
# ['scr', 'num']
# ['new', 'tree', 'structure', 'into', 'jspx']
# ['fixed', 'issue', 'with', 'saving', 'assertion', 'from', 'external', 'url']
# ['fixed', 'issue', 'with', 'tag', 'num']
# ['fixed', 'issue', 'with', 'completion', 'string']
# ['some', 'memory', 'optimizations', 'tokens', 'ends', 'created', 'if']
# ['fixed', 'issue', 'with', 'tag']
# ['fixed', 'issue', 'with', 'tag', 'string', 'for', 'selection']
# ['some', 'fixes', 'in', 'jsp', 'exception']
# ['fixed', 'issue', 'with', 'saving', 'assertion', 'from', 'external', 'url']
# ['fixed', 'issue', 'with', 'wrong', 'url']
# ['scr', 'num']
# ['fixed', 'npe', 'resolve', 'problem']
# ['scr', 'num', 'fixed', 'and']
# ['fixed', 'issue', 'with', 'tag', 'balancing', 'string']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'tag', 'num']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['fixed', 'issue', 'with', 'wrong', 'highlighting', 'of', 'end', 'html']
# ['fixed', 'issue', 'with', 'lexical', 'highlighting', 'of', 'whitespace', 'html']
# ['fixed', 'issue', 'with', 'lexical', 'highlighting', 'of', 'whitespace', 'html']
# ['some', 'more', 'back', 'and']
# ['fixed', 'npe', 'is', 'null', 'xmlfile', 'file']
# ['fixed', 'npe']
# ['custom', 'file', 'tags', 'completion']
# ['integraton', 'of', 'css', 'with', 'suitable']
# ['fixed', 'npe', 'get', 'that', 'null']
# ['fixed', 'npe', 'resolve', 'of', 'class', 'id']
# ['fixed', 'npe', 'with', 'null']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['test', 'manager', 'resource']
# ['removed', 'interrupted', 'check', 'in', 'aquire', 'processing']
# ['fixed', 'wrong', 'icons', 'in', 'module']
# ['fixing']
# ['rolled', 'back', 'stathik', 'changes']
# ['fix', 'for', 'reparse', 'at', 'file', 'body']
# ['removed', 'pattern', 'compiler', 'change']
# ['fixes', 'in', 'completion']
# ['update', 'for', 'resolve', 'and', 'some']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['tree', 'node', 'extends', 'node', 'for']
# ['tree', 'node', 'extends', 'node', 'for']
# ['new', 'tree', 'structure', 'into', 'support']
# ['scr', 'num', 'fixed', 'and']
# ['scr', 'num', 'fixed', 'and', 'keep', 'get', 'option']
# ['simple', 'jsp', 'completion', 'test']
# ['fixed', 'issue', 'with', 'parsing', 'attribute']
# ['fixed', 'bug', 'woth', 'resolve', 'of', 'class', 'id']
# ['some', 'tests', 'fixed', 'before']
# ['some', 'tests']
# ['some', 'tests', 'fixed']
# ['some', 'tests']
# ['some', 'tests', 'fixed']
# ['some', 'tests', 'fixed']
# ['some', 'tests', 'fixed']
# ['new', 'xml', 'structure']
# ['some', 'fixes', 'in', 'jsp', 'npe']
# ['xml', 'tag', 'get', 'value', 'test']
# ['new', 'tree', 'structure', 'into']
# ['some', 'tests', 'fixed']
# ['new', 'parser', 'get']
# ['some', 'tests', 'fixed', 'before']
# ['some', 'tests', 'fixed']
# ['some', 'tests', 'fixed', 'and', 'arrays']
# ['some', 'tests', 'fixed']
# ['test', 'fixed', 'around', 'map']
# ['some', 'tests', 'commented']
# ['some', 'tests', 'commented', 'jsp', 'for', 'jsp']
# ['new', 'xml', 'structure']
# ['test', 'fixed', 'option', 'updated']
# ['some', 'tests', 'fixed', 'and', 'tests']
# ['some', 'tests', 'fixed', 'for', 'jsp']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['some', 'tests', 'commented', 'fixed']
# ['some', 'tests']
# ['test', 'fixed', 'around', 'file']
# ['scr', 'num', 'get', 'get', 'tag']
# ['fixed', 'npe', 'file']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['fixing', 'num', 'leaks']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['extracted', 'abstract', 'tree', 'node', 'and', 'optimized', 'project', 'view']
# ['scr', 'num', 'of', 'completion', 'file']
# ['scr', 'num']
# ['rolled', 'back', 'stathik']
# ['tree', 'node', 'extends', 'node', 'for']
# ['tree', 'node', 'extends', 'node', 'for']
# ['tree', 'node', 'extends']
# ['commander', 'list', 'builder']
# ['scr', 'num']
# ['added', 'scr', 'num', 'keep', 'brace']
# ['scr', 'num', 'via']
# ['fixed', 'npe', 'scr', 'num']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['fixed', 'issue', 'with', 'forgiving', 'selection', 'for', 'first', 'find', 'edit']
# ['scr', 'num', 'fixed']
# ['scr', 'num']
# ['tree', 'node', 'extends', 'node', 'for']
# ['tree', 'node', 'extends']
# ['tree', 'node', 'contains']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['scr', 'num', 'fixed', 'and']
# ['scr', 'num', 'not', 'file']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['some', 'fixes', 'in', 'jsp', 'jsp']
# ['structure', 'veiw', 'tests']
# ['add', 'default', 'profile', 'cache', 'child']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['scr', 'num', 'fixed']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['scr', 'num', 'via']
# ['tree', 'node', 'extends', 'node', 'for', 'scr']
# ['reverted', 'back', 'module', 'groups']
# ['minor', 'cleanup', 'to', 'get', 'invalid']
# ['reverted', 'back', 'module', 'groups']
# ['splitters', 'compiler', 'during', 'parameter']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['commander', 'list', 'builder', 'test']
# ['splitters', 'compiler', 'during', 'parameter']
# ['minor', 'cleanup', 'null']
# ['minor', 'cleanup', 'null']
# ['scr', 'num', 'f']
# ['scr', 'num', 'f']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['added', 'usage', 'view', 'to', 'openapi', 'bundle']
# ['added', 'usage', 'view', 'to', 'openapi', 'bundle']
# ['tree', 'node', 'extends', 'node', 'for']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['extracted', 'abstract', 'tree', 'node', 'and', 'optimized', 'project', 'view']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['tree', 'node', 'extends', 'node', 'for']
# ['extracted', 'abstract', 'tree', 'node', 'and', 'optimized', 'project', 'view']
# ['fixed', 'npe', 'in', 'module', 'word']
# ['scr', 'num', 'corrected']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['tree', 'node', 'contains', 'virtual']
# ['tree', 'node', 'extends']
# ['fixed', 'issue', 'with', 'wrong', 'dir', 'for', 'first', 'find']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['tree', 'node', 'contains', 'virtual', 'for', 'css']
# ['tree', 'node', 'extends']
# ['tree', 'node', 'contains']
# ['commander', 'list']
# ['tree', 'node', 'extends']
# ['cce', 'in', 'ctrl', 'f']
# ['reverted', 'back', 'module', 'groups']
# ['tree', 'node', 'extends']
# ['tree', 'node', 'extends']
# ['tree', 'node', 'extends']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['scr', 'num']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['tree', 'node', 'extends']
# ['extracted', 'abstract', 'tree', 'node', 'project']
# ['scr', 'num']
# ['extracted', 'abstract', 'tree', 'node', 'and', 'optimized', 'project', 'view']
# ['commander', 'list', 'builder']
# ['extracted', 'abstract', 'tree', 'test', 'provider']
# ['extracted', 'abstract', 'tree', 'node', 'and', 'optimized', 'project', 'view']
# ['scr', 'num']
# ['scr', 'num', 'of', 'completion', 'file']
# ['integraton', 'of', 'document', 'builders', 'when', 'license', 'validation']
# ['fixed', 'issue', 'with', 'insertion', 'n']
# ['fixing', 'num']
# ['fixing', 'num', 'helper']
# ['fixing', 'num']
# ['xml', 'change', 'visitor']
# ['xml', 'change', 'visitor']
# ['xml', 'change', 'visitor']
# ['xml', 'change', 'visitor']
# ['xml']
# ['xml', 'change', 'visitor']
# ['xml', 'change', 'visitor']
# ['xml', 'change', 'visitor']
# ['scr', 'num']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['fixed', 'plugins', 'resource']
# ['fix', 'for', 'scr', 'file']
# ['fix', 'for', 'scr', 'file']
# ['fix', 'for', 'scr', 'num']
# ['jsp', 'resolve', 'in', 'jsp']
# ['fixed', 'npe', 'on', 'null', 'file']
# ['new', 'xml', 'structure']
# ['xml', 'notation', 'now']
# ['fixed', 'issue', 'with', 'tag', 'num', 'during', 'user']
# ['fixed', 'incorrect', 'replacement', 'problem']
# ['fixed', 'issue', 'with', 'id']
# ['fixed', 'issue', 'with', 'using', 'br', 'like']
# ['fixed', 'issue', 'with', 'id', 'reference', 'br']
# ['new', 'xml', 'structure']
# ['new', 'tree', 'structure', 'jspx']
# ['scr', 'num']
# ['new', 'tree', 'structure', 'into', 'jspx', 'build']
# ['fixed', 'npe', 'file', 'null', 'file']
# ['scr', 'num']
# ['scr', 'num']
# ['fixed', 'npe', 'null']
# ['fixed', 'issue', 'with', 'using', 'line']
# ['fixed', 'issue', 'with', 'completion', 'file']
# ['massive', 'changes', 'in', 'xml']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['fixed', 'issue', 'with', 'saving', 'file']
# ['num', 'of', 'wrap', 'comparator']
# ['fixed', 'read', 'by', 'allowed', 'assertion']
# ['fixed', 'issue', 'with', 'using', 'line']
# ['new', 'xml', 'structure', 'schema']
# ['html', 'psi']
# ['new', 'tree', 'structure', 'schema']
# ['reference', 'providers', 'registry', 'is']
# ['new', 'tree', 'structure', 'jspx']
# ['removed', 'classes', 'references']
# ['removed', 'classes', 'references']
# ['scr', 'num', 'to', 'get', 'editor']
# ['fixed', 'issue', 'with', 'user']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'filetype']
# ['scr', 'idea', 'num']
# ['fixed', 'issue', 'with', 'using', 'constant', 'in', 'xml', 'tag']
# ['removed', 'virtualfilesink', 'since', 'file', 'template']
# ['fixed', 'bug', 'num', 'of', 'switch', 'element']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'deferred', 'lookup']
# ['scr', 'num', 'and', 'fixed']
# ['scr', 'num', 'added']
# ['fixed', 'issue', 'with', 'completion', 'package']
# ['fixed', 'issue', 'with', 'parsing', 'library']
# ['some', 'fixes', 'in', 'resolve', 'exception', 'in', 'jsp']
# ['new', 'tree', 'structure', 'jspx']
# ['scr', 'num', 'and', 'completion', 'tag']
# ['fixed', 'npe', 'scr', 'num']
# ['fixed', 'problem', 'with', 'visitor', 'level']
# ['fixed', 'bug', 'with', 'wrong', 'completion', 'in']
# ['fixed', 'bug', 'woth', 'incorrect', 'selection', 'on', 'css', 'property']
# ['fixed', 'bug', 'woth', 'incorrect', 'selection', 'on', 'css', 'property']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['scr', 'num', 'helper', 'num']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'filetype']
# ['fix', 'for', 'scr', 'num']
# ['scr', 'num', 'not']
# ['added', 'testcase', 'factory', 'in', 'information', 'editor']
# ['scr', 'num']
# ['new', 'tree', 'structure', 'jspx']
# ['scr', 'num']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['fix', 'for', 'fabrique']
# ['scr', 'num', 'fixed', 'problem']
# ['scr', 'num']
# ['fixed', 'replace', 'by', 'symbol', 'bug']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'br']
# ['fixed', 'npe', 'in', 'select', 'word', 'file']
# ['fixed', 'npe', 'in', 'file', 'name']
# ['fixed', 'npe', 'in', 'select', 'word', 'in', 'block']
# ['tests', 'fixed', 'should', 'helper']
# ['fixed', 'issue', 'with', 'id', 'assert']
# ['fixed', 'issue', 'with', 'xml', 'file', 'by', 'external', 'url']
# ['splitters', 'during', 'not', 'scrambling']
# ['some', 'more', 'filtering', 'now', 'in', 'component']
# ['fixed', 'problem', 'with', 'itar', 'code']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'tag', 'attribute']
# ['scr', 'num', 'to', 'file']
# ['fixed', 'issue', 'with', 'saving', 'of', 'class']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'deferred', 'lookup']
# ['scr', 'num', 'option']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'br']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'filetype']
# ['fixed', 'npe', 'file']
# ['scr', 'num']
# ['fixing', 'num', 'version']
# ['fixing', 'num', 'leaks']
# ['fixing', 'num', 'leaks', 'if']
# ['fixing', 'num']
# ['fixing', 'num', 'leaks', 'if']
# ['fixing', 'num', 'leaks']
# ['fixing', 'num', 'leaks']
# ['new', 'tree', 'structure', 'into', 'jspx', 'build']
# ['fixing', 'num', 'leaks']
# ['fixing', 'num', 'leaks']
# ['fixed', 'issue', 'with', 'not', 'magic', 'completion', 'for', 'filetype']
# ['fixed', 'bug', 'num', 'of', 'switch', 'element']
# ['fixed', 'issue', 'with', 'xml', 'file']
# ['fixed', 'issue', 'with', 'xml']
# ['some', 'more', 'filtering', 'in', 'class', 'name']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['scr', 'num', 'get', 'tag', 'get']
# ['first', 'cut', 'for', 'live', 'templates', 'for', 'search', 'criterias']
# ['scr', 'num', 'get', 'tag', 'get']
# ['fixed', 'issue', 'with', 'expiring', 'user']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['fixed', 'npe', 'null', 'file']
# ['tests', 'fixed', 'during', 'fabrique']
# ['new', 'resolve', 'schema']
# ['fixing', 'num', 'leaks']
# ['fixed', 'issue', 'with', 'id', 'of', 'resource', 'map']
# ['fixed', 'issue', 'with', 'completion', 'line']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'in', 'filetype']
# ['fixed', 'issue', 'with', 'expiring', 'scriplet', 'in']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'filetype']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['fixed', 'npe', 'on', 'name']
# ['some', 'more', 'filtering', 'in', 'class', 'name']
# ['fixed', 'issue', 'with', 'cce', 'class']
# ['tree', 'node', 'extends', 'node', 'for', 'css']
# ['fixed', 'incorrect', 'replacement', 'problem']
# ['fixed', 'issue', 'with', 'id']
# ['scr', 'num']
# ['fixed', 'replace', 'by', 'symbol', 'bug']
# ['fixed', 'replace', 'by', 'symbol', 'bug']
# ['fixed', 'npe', 'with', 'selection']
# ['scr', 'num', 'and', 'tld', 'tag']
# ['scr', 'num', 'updated']
# ['scr', 'num', 'and', 'using', 'for', 'tag']
# ['scr', 'num', 'and', 'using']
# ['massive', 'changes', 'in', 'xml']
# ['massive', 'changes', 'in', 'xml', 'usage', 'in']
# ['fixed', 'npe', 'null', 'file']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'deferred', 'filetype']
# ['fixed', 'issue', 'with', 'not', 'eager', 'completion', 'for', 'deferred', 'filetype']
# ['scr', 'num']
# ['scr', 'num']
# ['structure', 'view', 'filters', 'tag']
# ['splitters', 'null', 'during', 'loading']
# ['structure', 'veiw', 'tests', 'completion']
# ['fixed', 'issue', 'with', 'using', 'line']
# ['fixed', 'npe', 'on', 'id']
# ['fixed', 'npe', 'is', 'not']
# ['scr', 'num', 'to', 'root', 'component']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['generics', 'resolve', 'with', 'substitutor', 'field']
# ['fixed', 'issue', 'with', 'using', 'exception']
# ['scr', 'num']
# ['reverted', 'back', 'module', 'groups']
# ['scr', 'num', 'helper']
# ['scr', 'num', 'to', 'get', 'assertion']
# ['scr', 'num', 'manager', 'to', 'get']
# ['tree', 'node', 'extends', 'node', 'for']
# ['fixed', 'npe', 'null']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'tag', 'balancing', 'user']
# ['fixed', 'issue', 'with', 'id', 'ik']
# ['fixed', 'issue', 'with', 'completion', 'paren']
# ['fixed', 'issue', 'with', 'using', 'completion', 'for']
# ['fixed', 'issue', 'with', 'not', 'magic', 'completion', 'for', 'lookup']
# ['fixed', 'issue', 'with', 'id', 'license']
# ['new', 'tree', 'structure', 'into']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'filetype']
# ['reverted', 'back', 'module', 'groups']
# ['scr', 'num', 'not', 'get']
# ['tree', 'node', 'extends']
# ['scr', 'num', 'get', 'hole', 'file']
# ['tree', 'node', 'extends']
# ['scr', 'num', 'get']
# ['tree', 'node', 'extends']
# ['structure', 'view', 'filters']
# ['fixed', 'issue', 'with', 'id', 'reference', 'br']
# ['tree', 'node', 'extends', 'node', 'by', 'check']
# ['fixed', 'issue', 'with', 'tag', 'method']
# ['fixed', 'problem', 'with', 'itar']
# ['fixed', 'bug', 'num', 'of', 'switch', 'element']
# ['fixed', 'issue', 'with', 'using', 'magic', 'completion', 'for', 'filetype']
# ['tree', 'node', 'extends']
# ['scr', 'num', 'not', 'file']
# ['tree', 'node', 'extends']
# ['reference', 'providers', 'registry', 'is']
# ['tree', 'node', 'extends']
# ['fixed', 'issue', 'with', 'complex', 'containing']
# ['scr', 'num']
# ['jspx', 'text', 'update']
# ['jspx', 'synchronization']
# ['jspx', 'synchronization']
# ['jspx', 'synchronization', 'and', 'jspx', 't']
# ['jspx', 'text', 'update', 'now']
# ['scr', 'num']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['fixed', 'issue', 'with', 'not', 'deferred']
# ['fixed', 'issue', 'with', 'jspx', 'resource']
# ['igor', 'k', 'styled']
# ['test', 'manager', 'add']
# ['fixed', 'issue', 'with', 'not']
# ['new', 'tree', 'structure', 'jspx']
# ['tree', 'node', 'extends', 'node', 'by', 'check']
# ['new', 'tree', 'structure']
# ['test', 'refactored', 'to', 'order']
# ['new', 'tree', 'structure', 'into', 'tab']
# ['fixed', 'find', 'sub', 'tag', 'file']
# ['pom', 'aspects', 'implemented']
# ['pom', 'aspects', 'implemented']
# ['events', 'in', 'case']
# ['pom', 'aspects', 'implemented']
# ['pom', 'aspects']
# ['pom', 'aspects', 'implemented']
# ['fixed', 'bug', 'text', 'merge']
# ['xml', 'tag', 'impl']
# ['new', 'xml', 'structure']
# ['events', 'in', 'case']
# ['pom', 'aspects']
# ['pom', 'aspects', 'implemented']
# ['some', 'tests', 'fixed']
# ['some', 'tests', 'fixed']
# ['pom', 'aspects', 'implemented']
# ['scr', 'num']
# ['scr', 'num']
# ['some', 'more', 'tesing', 'and', 'fix', 'enviroments']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['igor', 'k', 'styled']
# ['new', 'tree', 'structure']
# ['fixed', 'issue', 'with', 'completion']
# ['scr', 'num']
# ['scr', 'num']
# ['fixing', 'num', 'leaks']
# ['scr', 'num', 'to', 'project', 'docs']
# ['fixed', 'problem', 'with', 'name']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'saving', 'class']
# ['fixed', 'issue', 'with', 'saving', 'of']
# ['scr', 'num', 'get']
# ['reverted', 'back', 'module', 'groups']
# ['some', 'fixes', 'in', 'resolve', 'exception', 'npe']
# ['fixed', 'issue', 'with', 'tag', 'balancing', 'num']
# ['scr']
# ['fixed', 'issue', 'with', 'using', 'completion', 'in', 'lookup']
# ['fixed', 'issue', 'with', 'using', 'completion', 'in', 'lookup']
# ['some', 'more', 'filtering', 'in', 'class', 'name']
# ['some', 'more', 'filtering', 'in', 'class', 'name']
# ['some', 'more', 'filtering', 'in', 'class', 'name']
# ['added', 'fasten', 'formatting', 'child', 'replacement']
# ['added', 'fasten', 'formatting', 'child', 'replacement']
# ['added', 'scr', 'num', 'functionality']
# ['massive', 'changes', 'in', 'xml']
# ['massive', 'changes', 'in', 'xml']
# ['added', 'label', 'formatting', 'code', 'replacement', 'completion']
# ['fix', 'for', 'inheritor']
# ['added', 'usage', 'view', 'to', 'openapi', 'bundle']
# ['fixed', 'problem', 'with', 'visitor']
# ['fixed', 'replace', 'by', 'symbol', 'bug']
# ['new', 'parser', 'for']
# ['fixed', 'issue', 'with', 'using', 'user']
# ['fixed', 'issue', 'with', 'using', 'user']
# ['fixed', 'issue', 'with', 'tag', 'num', 'during', 'user']
# ['pom', 'aspects', 'implemented']
# ['invalid', 'tests', 'removed', 'again']
# ['pom', 'aspects']
# ['pom', 'aspects']
# ['fixed', 'issue', 'with', 'daemon', 'ns']
# ['invalid', 'tests', 'removed', 'again']
# ['splitters', 'of', 'wrap', 'done']
# ['splitters', 'algoritm', 'during', 'parameter']
# ['splitters', 'algoritm', 'of', 'parameter']
# ['splitters', 'algoritm', 'during', 'parameter']
# ['fixes', 'in', 'tests', 'tei']
# ['splitters', 'algoritm', 'during', 'parameter']
# ['splitters', 'algoritm', 'assignment', 'from', 'file']
# ['fixes', 'in', 'tests']
# ['splitters', 'of', 'wrap', 'done']
# ['splitters', 'algoritm', 'during', 'parameter', 'manager']
# ['added', 'read', 'methods', 'action', 'fixed']
# ['splitters', 'algoritm', 'during', 'parameter', 'factory']
# ['fixes', 'in', 'web', 'directory', 'resolve']
# ['xml', 'events', 'update', 'in', 'doctype']
# ['xml', 'events', 'update', 'in', 'doctype']
# ['removed', 'classes', 'caching']
# ['some', 'more', 'tesing', 'fix', 'for', 'ant']
# ['scr', 'num', 'to', 'project', 'component']
# ['scr', 'num', 'to', 'get']
# ['scr', 'num', 'should', 'map']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['update', 'for', 'resolve', 'and', 'some']
# ['num', 'of', 'wrap', 'designer']
# ['fixed', 'npe', 'autoindent', 'of', 'incorrect']
# ['fix', 'scr', 'num']
# ['scr', 'num', 'should', 'get']
# ['fixes', 'for', 'replacement', 'with', 'parameter', 'get']
# ['fixed', 'issue', 'with', 'file']
# ['fixed', 'bug', 'num', 'of', 'switch', 'id']
# ['fixed', 'npe', 'is']
# ['visibility', 'comparator', 'fixed']
# ['sh', 'mem', 'for', 'j', 'num']
# ['class', 'name', 'completion']
# ['fixed', 'issue', 'with', 'id', 'assert']
# ['visibility', 'comparator', 'fixed']
# ['removed', 'pattern', 'compiler', 'startup']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['several', 'classes', 'support', 'in', 'one']
# ['class', 'name', 'completion']
# ['added', 'css', 'xhtml']
# ['fixed', 'issue', 'with', 'completion', 'string']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['fixes', 'for', 'num', 'get']
# ['rolled', 'back', 'stathik', 'merge']
# ['support', 'for', 'quick', 'length']
# ['sh', 'mem', 'for', 'j', 'num']
# ['rolled', 'classes', 'support', 'in', 'one']
# ['rolled', 'back', 'stathik']
# ['fixing', 'num']
# ['fixes', 'for', 'num', 'get']
# ['rolled', 'back', 'stathik']
# ['added', 'read', 'action', 'rule']
# ['scr', 'num']
# ['fixing', 'num']
# ['fixed', 'read', 'access', 'allowed']
# ['patterns', 'are', 'separated', 'from']
# ['sh', 'mem', 'for', 'j', 'num']
# ['saving', 'npe', 'not', 'lists']
# ['rolled', 'back', 'stathik', 'changes']
# ['fixed', 'issue', 'with', 'saving', 'dir']
# ['fixing', 'num']
# ['rolled', 'back', 'stathik', 'changes']
# ['fixed', 'issue', 'with', 'expiring', 'completion', 'in', 'xml']
# ['fixed', 'npe', 'on', 'loading', 'class']
# ['tests', 'fixed', 'option', 'for']
# ['fixes', 'in', 'completion', 'tld']
# ['scr', 'idea', 'num']
# ['rolled', 'back', 'stathik', 'changes', 'for', 'css']
# ['rolled', 'back', 'stathik', 'changes']
# ['rolled', 'back', 'stathik', 'changes']
# ['fixed', 'read', 'access', 'allowed']
# ['fix', 'for', 'scr', 'num']
# ['fixing']
# ['some', 'tests', 'fixed']
# ['jspx', 'synchronization', 'jspx', 'to', 'support', 'docs']
# ['tree', 'events', 'into']
# ['new', 'xml', 'structure']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['jspx', 'synchronization', 'jspx', 'to', 'support']
# ['new', 'tree', 'structure', 'into', 'jspx']
# ['some', 'minor', 'fixes']
# ['fixed', 'issue', 'with', 'prevent']
# ['some', 'fixes', 'in', 'reparse', 'jsp']
# ['fixed', 'issue', 'with', 'insertion', 'of', 'n']
# ['scr', 'num', 'fixed']
# ['new', 'xml', 'structure']
# ['scr']
# ['scr', 'num']
# ['refactoring', 'with', 'named', 'element']
# ['tree', 'structure', 'provider']
# ['fixed', 'npe', 'on', 'file']
# ['new', 'tree', 'structure', 'jspx']
# ['scr', 'num']
# ['scr', 'num', 'fixed', 'out', 'completion', 'file']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['massive', 'changes', 'in', 'jsp', 'evaluation']
# ['jsp', 'implicit', 'variables', 'rewriten', 'now']
# ['fixed', 'process', 'declarations', 'for', 'resolve', 'q']
# ['update', 'for', 'resolve', 'and', 'some']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['scr', 'num', 'and', 'completion', 'tag']
# ['test', 'fixed', 'around', 'map']
# ['some', 'tests', 'commented']
# ['some', 'tests', 'commented']
# ['new', 'tests']
# ['test', 'fixed', 'around', 'case', 'file']
# ['new', 'tests']
# ['new', 'tests']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['new', 'tests']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['fixes', 'in', 'tests', 'tei']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['new', 'xml', 'structure']
# ['fixing', 'num', 'to', 'keep']
# ['new', 'block', 'support', 'into', 'case']
# ['new', 'tree', 'structure', 'evaluation']
# ['scr', 'num']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['new', 'ant', 'support', 'case']
# ['added', 'intentions', 'and', 'inspections', 'plugins', 'back']
# ['some', 'tests', 'fixed', 'made', 'if']
# ['test', 'fixed', 'around', 'map']
# ['some', 'tests', 'commented']
# ['fixed', 'issue', 'with', 'validation', 'finding', 'file', 'from', 'external', 'url']
# ['some', 'tests', 'commented', 'jsp', 'for', 'jsp']
# ['some', 'tests', 'fixed']
# ['test', 'fixed', 'option', 'updated']
# ['new', 'xml', 'structure']
# ['some', 'tests', 'commented']
# ['fixed', 'one', 'more', 'html', 'tag']
# ['fixed', 'issue', 'with', 'complex', 'file']
# ['fixed', 'issue', 'with', 'not', 'magic', 'completion', 'for', 'deferred', 'filetype']
# ['test', 'fixed', 'around', 'file']
# ['some', 'tests', 'fixed']
# ['some', 'tests', 'fixed', 'before']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['test', 'resource', 'from', 'support']
# ['test', 'fixed', 'around', 'map']
# ['some', 'tests', 'commented']
# ['some', 'tests', 'commented', 'and']
# ['some', 'tests', 'commented']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['test', 'fixed', 'around', 'start', 'file']
# ['some', 'tests', 'commented']
# ['some', 'tests', 'commented']
# ['test', 'resource', 'from', 'support', 'xml']
# ['test', 'fixed', 'around', 'file']
# ['test', 'resource', 'from', 'support']
# ['some', 'tests', 'commented']
# ['test', 'fixed', 'around', 'file']
# ['fixed', 'issue', 'with', 'method']
# ['fixed', 'npe', 'on']
# ['test', 'fixed', 'option', 'updated']
# ['test', 'manager']
# ['test', 'manager']
# ['test', 'to', 'be', 'start']
# ['add', 'default', 'profile', 'hint', 'bug', 'fix']
# ['several', 'classes', 'support', 'in', 'one']
# ['add', 'default', 'hint']
# ['patterns', 'are', 'separated', 'from', 'fabrique']
# ['fixes', 'for', 'resolve', 'with', 'completion', 'method']
# ['add', 'default', 'hint']
# ['tests', 'fixed', 'should', 'be', 'updated', 'for', 'clone', 'file']
# ['indent', 'working', 'wrap']
# ['new', 'tree', 'structure', 'into', 'parent', 'start']
# ['test', 'bug', 'num']
# ['test', 'manager', 'wrap']
# ['test', 'option']
# ['test', 'checks', 'for', 'test', 'docs']
# ['test', 'manager', 'option', 'updated']
# ['test', 'manager', 'resource', 'done']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['test', 'variant']
# ['fixed', 'npe', 'on', 'file']
# ['num', 'of', 'wrap', 'done']
# ['test', 'option', 'removed']
# ['test', 'version', 'of', 'wrap']
# ['test', 'option']
# ['indent', 'working', 'wrap']
# ['test', 'disabled', 'to', 'be', 'file']
# ['test', 'manager', 'wrap']
# ['test', 'version']
# ['test', 'used', 'num', 'of', 'test']
# ['new', 'tree', 'structure', 'into']
# ['test', 'version']
# ['test', 'version', 'of', 'type']
# ['test', 'on', 'parent', 'level']
# ['test', 'version', 'of', 'lookahead']
# ['num', 'of', 'wrap', 'done']
# ['test', 'version']
# ['test', 'is', 'parent']
# ['test', 'option', 'removed']
# ['test', 'option', 'removed']
# ['whitespace', 'fix', 'chameleon']
# ['supported', 'line', 'comment', 'for', 'css', 'html']
# ['new', 'block', 'support', 'into', 'xml', 'case', 'for', 'css']
# ['new', 'tree', 'structure', 'jspx']
# ['new', 'tree', 'structure']
# ['new', 'tree', 'structure', 'into', 'jspx', 'generation']
# ['new', 'tree', 'structure', 'in']
# ['test', 'token', 'to', 'text', 'short']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['test', 'generated', 'be']
# ['fixed', 'startin', 'write', 'action', 'file']
# ['test', 'manager', 'parent', 'to', 'start', 'map']
# ['scr', 'num', 'of', 'keep', 'offset']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['indent', 'working', 'wrap']
# ['indent', 'working', 'wrap']
# ['test', 'version']
# ['fixed', 'npe', 'on', 'file']
# ['test', 'of', 'jsp', 'num']
# ['test', 'resource', 'start']
# ['scr', 'num', 'made']
# ['test', 'manager', 'parent']
# ['simple', 'jsp', 'completion', 'test']
# ['test', 'of', 'keep', 'docs']
# ['test', 'resource', 'start']
# ['test', 'message', 'for', 'jsp', 'test']
# ['test', 'token', 'in', 'case', 'id']
# ['test', 'manager', 'wrap']
# ['test', 'manager', 'code', 'in', 'case', 'chameleon']
# ['test', 'manager']
# ['test', 'manager', 'token']
# ['add', 'default', 'profile', 'hint', 'commit']
# ['patterns', 'are', 'separated', 'from', 'fabrique']
# ['add', 'default', 'hint']
# ['fixed', 'npe', 'on', 'null', 'file']
# ['fixes', 'in', 'completion', 'get']
# ['add', 'default', 'hint']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'wrong', 'dir', 'for', 'first', 'find']
# ['fixed', 'npe', 'null', 'tag', 'name']
# ['fixed', 'npe', 'null', 'tag', 'name']
# ['fix', 'for', 'npe', 'in', 'tree', 'structure', 'bug']
# ['scr', 'num']
# ['fixing', 'num']
# ['test', 'used', 'test']
# ['fixing', 'num', 'leaks', 'if']
# ['scr', 'num']
# ['some', 'fixes', 'in', 'jsp', 'jsp']
# ['fixing', 'num', 'leaks']
# ['fixing', 'num', 'if']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['some', 'more', 'filtering', 'class', 'name']
# ['fixing', 'num', 'if']
# ['scr', 'num', 'and', 'tld', 'q']
# ['support', 'for', 'module', 'in']
# ['support', 'for', 'module', 'in']
# ['scr', 'num']
# ['scr', 'num']
# ['new', 'xml', 'structure']
# ['support', 'foreach', 'selectors', 'in', 'css', 'body']
# ['new', 'tree', 'structure', 'performance']
# ['new', 'tree', 'structure', 'performance']
# ['resolve', 'in', 'multyroot', 'environment']
# ['scr', 'idea']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ...
# ['new', 'tests', 'for', 'jsp']
# ['performance', 'leak', 'fixed']
# ['test', 'for', 'igor', 'kuralenok']
# ['new', 'tests']
# ['new', 'tests', 'for', 'jsp']
# ['test', 'for', 'igor', 'kuralenok']
# ['parser', 'state', 'interface', 'changed']
# ['new', 'tests']
# ['new', 'tests']
# ['new', 'tests']
# ['new', 'parsing', 'now']
# ['test', 'fixed', 'option', 'in', 'case']
# ['new', 'tests']
# ['xml', 'notation', 'parsing', 'doctype']
# ['test', 'fixed', 'problem', 'to', 'provide', 'parsed']
# ['new', 'tests']
# ['new', 'tests', 'for', 'jsp']
# ['performance', 'leak', 'fixed']
# ['performance', 'leak', 'fixed']
# ['new', 'tests']
# ['performance', 'leak', 'fixed']
# ['performance', 'leak', 'fixed', 'and', 'tests']
# ['new', 'tests']
# ['test', 'for', 'igor', 'kuralenok']
# ['test', 'for', 'igor', 'kuralenok']
# ['test', 'for', 'igor', 'kuralenok']
# ['new', 'parsing', 'now', 'is', 'production']
# ['new', 'tests']
# ['xml', 'notation', 'parsing', 'doctype']
# ['test', 'fixed', 'problem']
# ['performance', 'leak', 'fixed']
# ['new', 'tests']
# ['new', 'tests', 'for', 'jsp']
# ['new', 'tests', 'for', 'jsp']
# ['new', 'parsing', 'now']
# ['new', 'tests', 'for', 'jsp']
# ['xml', 'notation', 'parsing', 'doctype']
# ['performance', 'leak', 'fixed']
# ['xml', 'notation', 'parsing', 'doctype']
# ['new', 'tests']
# ['new', 'tests']
# ['new', 'tests', 'for', 'jsp']
# ['performance', 'leak', 'fixed']
# ['performance', 'leak', 'fixed']
# ['new', 'tests']
# ['new', 'parsing', 'now']
# ['parser', 'state', 'interface', 'changed']
# ['new', 'tests']
# ['xml', 'notation', 'parsing', 'doctype']
# ['performance', 'leak', 'fixed']
# ['xml', 'notation', 'parsing', 'doctype']
# ['new', 'parsing', 'now']
# ['test', 'fixed', 'problem', 'to', 'provide', 'parsed']
# ['test', 'fixed', 'option', 'for', 'jsp', 'dtd']
# ['test', 'fixed', 'problem']
# ['new', 'tests']
# ['new', 'tests']
# ['parser', 'state', 'interface', 'changed']
# ['performance', 'leak', 'fixed']
# ['xml', 'notation', 'parsing', 'doctype']
# ['performance', 'leak', 'fixed']
# ['test', 'fixed', 'option', 'in', 'method', 'access', 'in']
# ['performance', 'leak', 'fixed']
# ['new', 'tests']
# ['new', 'tests', 'for', 'jsp']
# ['performance', 'leak', 'fixed']
# ['performance', 'leak', 'fixed']
# ['performance', 'leak', 'fixed']
# ['parser', 'state', 'interface', 'changed']
# ['new', 'tests']
# ['some', 'minor', 'fixes']
# ['performance', 'leak', 'fixed']
# ['xml', 'notation', 'parsing', 'doctype']
# ['new', 'tests', 'for', 'jsp']
# ['performance', 'leak', 'fixed']
# ['new', 'tests']
# ['parser', 'state', 'interface', 'changed']
# ['new', 'tests', 'for', 'method']
# ['performance', 'leak', 'fixed']
# ['indent', 'working', 'wrap']
# ['completing', 'even', 'if', 'tag', 'start', 'with', 'whitespace']
# ['fixed', 'issue', 'with', 'wrong', 'dir', 'for', 'first', 'find', 'map']
# ['jsp', 'fixes', 'includes']
# ['scr', 'num', 'option']
# ['script', 'is', 'integrated', 'with', 'file']
# ['performance', 'leak', 'fixed', 'and', 'tests']
# ['scr', 'num']
# ['simple', 'jsp', 'completion', 'test']
# ['new']
# ['generics', 'resolve', 'with', 'substitutor', 'num']
# ['new', 'tree', 'structure', 'jspx']
# ['parsing', 'css', 'inside', 'html']
# ['test', 'option', 'again']
# ['add', 'support', 'for', 'different', 'cut']
# ['rolled', 'back', 'stathik', 'changes']
# ['add', 'support', 'for', 'different', 'cut', 'ui']
# ['rolled', 'back', 'stathik', 'changes']
# ['fixed', 'xml', 'highlighting', 'in', 'complex']
# ['rolled', 'back', 'stathik']
# ['rolled', 'back', 'stathik', 'changes']
# ['added', 'css', 'xhtml']
# ['rolled', 'back', 'stathik']
# ['clean', 'up', 'option', 'references']
# ['fixing', 'non', 'compilable', 'code', 'with']
# ['lexer', 'script', 'states', 'to']
# ['added', 'usage', 'view', 'to', 'openapi', 'bundle']
# ['fix', 'for', 'scr', 'num']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['added', 'css', 'xhtml', 'binding', 'cut']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['jsp', 's', 'now', 'support', 'completion']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['new', 'tree', 'structure', 'schema']
# ['scr', 'num', 'get', 'tag', 'get']
# ['scr', 'num', 'get', 'tag', 'get']
# ['new', 'xml', 'structure']
# ['fixed', 'issue', 'with', 'not', 'magic', 'completion', 'lookup']
# ['added', 'several', 'methods', 'to', 'convert', 'collection', 'array']
# ['scr', 'idea', 'num']
# ['scr', 'num', 'helper']
# ['fixed', 'npe', 'on', 'null', 'containing', 'in', 'content', 'file']
# ['added', 'parent', 'formatting', 'code', 'of', 'html']
# ['some', 'fixes', 'in', 'jsp', 'highlighting']
# ['added', 'support', 'for', 'multi', 'line']
# ['visibility', 'comparator', 'fixed']
# ['added', 'support', 'for', 'dag', 'like', 'type', 'ext']
# ['values', 'use', 'defs', 'highlighting', 'for']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['refactored', 'to', 'speedup']
# ['fixed', 'issue', 'with', 'completion']
# ['test', 'manager']
# ['resolve', 'in', 'multyroot', 'environment']
# ['values', 'use', 'defs', 'highlighting', 'file']
# ['scr', 'num', 'and', 'order', 'fix']
# ['jsp', 'implicit', 'variables']
# ['some', 'fixes', 'in', 'jsp', 'tld']
# ['some', 'fixes', 'in', 'jsp', 'jsp']
# ['some', 'fixes', 'in', 'jsp', 'jsp']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['jsp', 'fixes', 'and', 'jsp', 'support', 'in']
# ['fixed', 'npe', 'on', 'name']
# ['scr', 'num']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['values', 'use', 'defs', 'highlighting', 'array']
# ['values', 'use', 'defs', 'highlighting', 'for']
# ['values', 'use', 'defs']
# ['several', 'fixes', 'in', 'new', 'support']
# ['refactored', 'to', 'speedup']
# ['values', 'use', 'defs']
# ['values', 'use', 'defs']
# ['fixed', 'npe', 'on', 'psi', 'name']
# ['values', 'use', 'defs', 'highlighting']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['fixed', 'issue', 'with', 'parsing']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['significant', 'ui', 'tweaks', 'first', 'cut']
# ['values', 'find', 'usages', 'of', 'class', 'file']
# ['values', 'use', 'defs', 'highlighting', 'file']
# ['values', 'use', 'defs', 'highlighting']
# ['values', 'use', 'defs', 'highlighting']
# ['fixed', 'issue', 'with', 'tag', 'line']
# ['values', 'use', 'defs', 'highlighting', 'array']
# ['values', 'use', 'defs', 'highlighting', 'for']
# ['resolve', 'in', 'multyroot', 'environment']
# ['scr', 'num', 'helper', 'get', 'tag', 'get']
# ['jsp', 'implicit', 'variables', 'rewriten']
# ['values', 'find', 'usages', 'of', 'class', 'file']
# ['values', 'use', 'defs', 'replacement', 'location']
# ['scr', 'num', 'to', 'keep', 'start']
# ['values', 'find', 'usages', 'of', 'class', 'file']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['jsp', 'fixes', 'and', 'jsp', 'support', 'in', 'jsp']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['first', 'cut', 'for', 'live', 'templates', 'for', 'search', 'criterias']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['values', 'use', 'defs', 'highlighting', 'replacement']
# ['scr', 'num']
# ['scr', 'num', 'values']
# ['first', 'cut', 'for', 'live', 'templates', 'for', 'search', 'criterias']
# ['scr', 'num', 'to', 'project']
# ['scr', 'num', 'to', 'get', 'super']
# ['scr', 'num', 'and', 'return', 'option']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'fixed']
# ['fix', 'scr', 'num']
# ['scr', 'num', 'and', 'plugin', 'tag']
# ['scr', 'num', 'and', 'plugin', 'tag']
# ['scr', 'num', 'and', 'plugin', 'tag']
# ['scr', 'num', 'and', 'plugin', 'tag']
# ['scr', 'num', 'of', 'optional', 'map']
# ['fixed', 'issue', 'with', 'completing', 'action']
# ['scr', 'num']
# ['scr', 'num', 'bit']
# ['scr', 'num', 'and', 'completion']
# ['scr', 'num', 'to', 'project']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'and', 'manager', 'jspx']
# ['scr', 'num', 'and', 'tld', 'place']
# ['scr', 'num']
# ['scr', 'num', 'and', 'problem', 'get']
# ['scr', 'num']
# ['scr']
# ['scr', 'num']
# ['time', 'bomb', 'only']
# ['time', 'bomb', 'try']
# ['added', 'css', 'xhtml', 'binding', 'cut']
# ['several', 'classes', 'support', 'in', 'one']
# ['rolled', 'back', 'stathik']
# ['fixed', 'npe', 'in', 'finding', 'selection', 'in', 'processot']
# ['fix', 'for', 'num', 'tld']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['form', 'merger', 'tree', 'structure', 'provider']
# ['fixed', 'npe', 'get', 'null']
# ['fixed', 'issue', 'with', 'wrong', 'dir', 'for', 'first', 'find']
# ['scr', 'num']
# ['fixed', 'issue', 'with', 'truncation', 'of', 'number', 'count']
# ['scr', 'num']
# ['num', 'com', 'intellij']
# ['fixed', 'issue', 'with', 'highlighting', 'resource', 'like']
# ['fix', 'for', 'npe', 'outside']
# ['fixes', 'for', 'replacement', 'with', 'parameter', 'get']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['new', 'xml', 'structure']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['new', 'parser', 'added']
# ['fixed', 'npe', 'on']
# ['fixed', 'npe', 'on']
# ['fixed', 'npe', 'on', 'file']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['jspx', 'fix', 'minimal', 'jspx', 'support']
# ['new', 'xml', 'structure', 'schema']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['fixed', 'issue', 'with', 'id', 'dependent', 'as', 'url']
# ['new', 'xml', 'structure']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['scr', 'num']
# ['scr', 'num']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['fix', 'for', 'scr', 'num']
# ['performance', 'optimization', 'for', 'jsp', 'xml']
# ['new', 'resolve', 'schema']
# ['several', 'fixes', 'in', 'resolve']
# ['scr', 'num', 'and', 'expiring', 'for', 'scr']
# ['scr', 'num', 'and', 'methods', 'changes']
# ['scr', 'num']
# ['scr', 'num', 'get']
# ['scr', 'num']
# ['completion', 'fixes', 'and', 'expressions']
# ['scr', 'num']
# ['supported', 'import', 'keyword', 'completion', 'fixed']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['fixed', 'npe', 'is', 'inserted']
# ['scr', 'num']
# ['fixed', 'find', 'use', 'file', 'body']
# ['scr', 'num', 'to', 'support']
# ['scr', 'num']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['scr', 'num', 'fixed']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['scr', 'num', 'get']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['scr', 'num', 'and', 'tld', 'scr']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['scr', 'num', 'to', 'get', 'map']
# ['scr', 'num', 'and', 'option', 'file']
# ['scr', 'num', 'should', 'map']
# ['scr', 'num', 'get']
# ['scr', 'num', 'and', 'option', 'scr']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['implementation', 'of', 'document', 'guarded', 'required', 'by', 'compu', 'ware']
# ['scr', 'num', 'get', 'substitutor']
# ['scr', 'num', 'to', 'project', 'presentable']
# ['scr', 'num']
# ['scr', 'num']
# ['completion', 'fixes', 'and']
# ['fix', 'for', 'is', 'inheritor']
# ['scr', 'num', 'to', 'project', 'presentable']
# ['class', 'name', 'completion']
# ['scr', 'num', 'to', 'project', 'impl']
# ['some', 'tests', 'fixed']
# ['scr', 'num', 'get']
# ['scr', 'num']
# ['scr', 'num', 'helper', 'file']
# ['scr']
# ['scr', 'num', 'and', 'move', 'option']
# ['scr', 'num', 'and', 'methods']
# ['scr', 'num']
# ['scr', 'num', 'to', 'get', 'loading']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'and']
# ['scr', 'num', 'get', 'file']
# ['scr', 'num', 'get', 'file']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'fixed', 'and', 'licenses']
# ['generics', 'resolve', 'with', 'substitutor', 'improovement']
# ['working', 'search', 'in', 'selection', 'html']
# ['scr', 'num', 'get', 'clone']
# ['working', 'on', 'add', 'methods', 'generation']
# ['fix', 'for', 'scr', 'num']
# ['fixed', 'issue', 'with', 'not', 'running', 'num', 'for', 'global']
# ['fix', 'for', 'fix', 'fix']
# ['fixed', 'issue', 'with', 'forgiving', 'selection', 'for', 'history', 'find']
# ['fixed', 'html', 'performance', 'tests']
# ['fixed', 'issue', 'with', 'truncation', 'of', 'number', 'count']
# ['fixing', 'num', 'leaks']
# ['scr', 'num', 'fixed']
# ['fixed', 'issue', 'with', 'truncation', 'of', 'number', 'count']
# ['update', 'for', 'resolve', 'and', 'some']
# ['reverted', 'back', 'dave', 's', 'to']
# ['scr', 'num', 'length', 'bug']
# ['time', 'bomb', 'to', 'be', 'contract']
# ['time', 'bomb']
# ['new', 'tree', 'structure', 'into']
# ['script', 'is', 'integrated', 'with', 'file']
# ['new', 'tree', 'structure', 'into']
# ['time', 'bomb']
# ['time', 'bomb']
# ['new']
# ['new', 'parser', 'time']
# ['parsing', 'css', 'inside', 'html', 'html']
# ['new', 'parser', 'in', 'get', 'end']
# ['first', 'replace', 'statement', 'expression', 'implementation']
# ['time', 'bomb']
# ['scr', 'num', 'and', 'rid']
# ['scr', 'num', 'and', 'body']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'scr']
# ['scr', 'num']
# ['working', 'on', 'add', 'methods', 'with', 'stand']
# ['scr']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'fixed', 'and']
# ['scr', 'num', 'helper', 'file']
# ['fix', 'for', 'scr', 'num']
# ['scr', 'num']
# ['fix', 'for', 'scr', 'num']
# ['scr', 'num', 'view']
# ['fix', 'for', 'scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'fixed', 'and']
# ['scr', 'num']
# ['scr', 'num', 'of', 'completion', 'assertion']
# ['scr', 'num', 'and', 'root', 'assertion']
# ['scr', 'num', 'helper', 'scr']
# ['scr', 'num', 'should', 'get']
# ['scr', 'num', 'and', 'new', 'get', 'impl']
# ['scr', 'num']
# ['generics', 'resolve', 'with', 'substitutor', 'performance']
# ['scr', 'num']
# ['rewrote', 'caches', 'for', 'find', 'super']
# ['scr']
# ['scr']
# ['scr', 'num']
# ['scr', 'num', 'and', 'get']
# ['scr', 'num']
# ['completion', 'after', 'generics', 'in']
# ['new', 'resolve', 'schema']
# ['scr', 'num']
# ['scr', 'num']
# ['scr', 'num', 'fixed']
# ['ide', 'document', 'history', 'uses']
# ['added', 'performance', 'and', 'xml', 'test', 'fabrique']
# ['new', 'parser', 'for', 'jsp']
# ['reverted', 'back', 'module', 'groups']
# ['tabs', 'refactored', 'to', 'outer', 'space', 'custom']
# ['test']
# ['test']
# ['test', 'manager', 'resource']
# ['test', 'kuralenok']
# ['test']
# ['test', 'manager', 'methods']
# ['test']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-157-e048484fdd91> in <module>
#       3 for commit in commit_vs_predicted_message.keys():
#       4     for token_and_tags in commit_vs_predicted_message[commit]:
# ----> 5         filtered_predicted_messages[commit].append(filter_tags_by_probability(token_and_tags))
#
# <ipython-input-156-150f8fc94d8e> in filter_tags_by_probability(tokens_and_tags, threshold)
#      37
#      38     for token, tag in tokens_and_tags[mid:]:
# ---> 39         proba = get_proba(tag, resulted_tuples)
#      40         if proba > threshold:
#      41             resulted_tuples.append((token, tag))
#
# <ipython-input-156-150f8fc94d8e> in get_proba(tag, resulted_token_and_tags)
#      10         return bigram_proba + threegram_proba
#      11     else:
# ---> 12         prev_tag = resulted_token_and_tags[-1][1]
#      13         return model.score(tag, prev_tag)
#      14
#
# IndexError: list index out of range

# %% [markdown]
# # Merge all messages in one

# %%
def get_common_message_prefix(messages: List[List[str]]) -> Optional[List[str]]:
    result_tokens = []
    max_size = max([len(message) for message in messages])
    
    for i in range(max_size):
        tokens_slice = []
        for message in messages:
            try:
                tokens_slice.append(message[i])
            except IndexError:
                pass
        counter = Counter(tokens_slice)
        result_tokens.append(max(counter, key=counter.get))

        if result_tokens in messages:
            return result_tokens
    return None

def leave_only_one_message_per_commit(messages: List[List[str]]) -> str:
    messages_str = [" ".join([token for token in message]) for message in messages]
    unique_messages = set(messages_str)
    if len(messages_str) > len(unique_messages):
        counter = Counter(messages_str)
        max_message = max(counter, key=counter.get)
        number_of_dublicates = counter[max_message]
        if number_of_dublicates > 1:
            return max_message
    
    common_message: List[str] = get_common_message_prefix(messages)
    if common_message:
        return " ".join(common_message)
 
    return "massive changes"
        
# tests
a = [['fixed', 'another', 'issue', 'with', 'xml'],
    ['scr', 'num', 'get', 'file'],
    ['add', 'source', 'specification'],
    ['fixed', 'another', 'issue', 'with', 'xml', 'url'],
    ['add', 'children', 'profile'],
    ['add', 'default', 'hint'],
    ['add', 'default'],
    ['add', 'default', 'profile', 'hint', 'completion'],
    ['add', 'default', 'hint']]
print(f"max = {leave_only_one_message_per_commit(a)}")
# for commit in filtered_predicted_messages.keys():
# Out:
# max = add default hint

# %%
one_message_vs_commit: List[Dict[str, str]] = []

for commit in filtered_predicted_messages.keys():
    one_message_vs_commit.append({"commit" : commit,
                                  "message": leave_only_one_message_per_commit(filtered_predicted_messages[commit])})

# %%
# k = 0
# for commit, message in one_message_vs_commit:
#     if message == "massive changes":
#         k += 1

# print(f"Number of MCH {k}, {k / len(one_message_vs_commit.keys())}")
# Out:
# Number of MCH 17, 0.02936096718480138

# %% [markdown]
# ## Write result

# %%
csv_out_file = "/Users/natalia.murycheva/Documents/code2seq/filtered.code2seq.result.csv"

csv_columns = ["commit", "message"]
try:
    with open(csv_out_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in one_message_vs_commit:
            writer.writerow(data)
except IOError:
    print("I/O error")
